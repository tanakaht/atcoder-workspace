# %%
import math
import matplotlib.pyplot as plt
N = 100000
dp = [0]*N
cumsum = [0]*N
dp[1] = 1
cumsum[1] = 1
for i in range(2, N):
    dp[i] = cumsum[int(math.sqrt(i))]
    cumsum[i] = cumsum[i-1]+dp[i]
plt.plot(range(N), dp)
plt.show()
