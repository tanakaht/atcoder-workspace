# %%
cur = 1
cnt = 1
cnt2 = 0
ls = []
for i in range(2, 100):
    flg = True
    for j in range(2, i):
        if i % j == 0:
            flg = False
            break
    if flg:
        ls.append(i)
        cur *= i
        cnt *= 2
        cnt2 += 1
    if cur>10**16:
        break
print(cur, cnt, cnt2, i)
# Out:
# 13082761331670030 16384 14 43

# %%
M = cur/i
ls.pop()
# Out:
# 43

# %%
import random
for _ in range(2*10**5):
    x = 1
    for i in ls:
        if random.random() < 0.5:
            x *= i
    print(x, end=' ')
# Out:
# 71386986 21732161680515 161724706 65557048810 520030 434444010 148074 476556366 72020130 6582485 91 1217370 161724706 213893966 354604036745 3131310 3215630 2465554 1360749 160119498 9024510 27981065 122322 808623530 1195289810 158730 2031992677 15001613 44485 410205 32124407510 12441 1191946342 79373 1107738190 2017610 6191094 49958992369 16431922 149682390 510081 486637690 497002 3026415 855811110 2114743510 14784055 986 33046 2238533374 2810314455 3698331 811965 6 121693 458948490 4619265 149876977107 3150338730 271126713 51449055 242535 1285570 4537470 4902247 2233 281010 1001459030 18405944557 130554578 790260424746 1924111 1363783 5172970 217 2936830 10455 51578 67373670 9915815 1325155 33046 42647920315 69851782 3637151 13502430370 58987110 2021126406 2109772301 51875577754 693966 8747348155 646 634956630 12440362 23467990 636405 11218215 302498 42671846217 12792738 13370699342 103599210 451605 2660203 206770 11528998239 198030 965426385 274873 14655498 991437195 41914418 1415
# ...
